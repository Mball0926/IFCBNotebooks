# %%
# %matplotlib inline

import numpy as np
from pandas import Series, DataFrame
import pandas as pd
import datetime as dt

import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import requests
import json
import re

# %%
humid=[{"date": "2016-07-10T00:17:50Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_001750", "humidity": 3.67524348144531}, {"date": "2016-07-10T00:50:50Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_005050", "humidity": 3.42335737304688}, {"date": "2016-07-10T01:14:01Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_011401", "humidity": 3.95619337158203}, {"date": "2016-07-10T01:37:48Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_013748", "humidity": 3.73337104492188}, {"date": "2016-07-10T02:01:01Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_020101", "humidity": 3.25866260986328}, {"date": "2016-07-10T02:23:39Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_022339", "humidity": 3.74305897216797}, {"date": "2016-07-10T02:47:26Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_024726", "humidity": 4.17901569824219}, {"date": "2016-07-10T03:10:38Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_031038", "humidity": 3.12303162841797}, {"date": "2016-07-10T03:33:16Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_033316", "humidity": 3.89806580810547}, {"date": "2016-07-10T03:56:27Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_035627", "humidity": 4.41152595214844}, {"date": "2016-07-10T04:20:17Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_042017", "humidity": 3.849626171875}, {"date": "2016-07-10T04:42:53Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_044253", "humidity": 3.88837788085938}, {"date": "2016-07-10T05:06:04Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_050604", "humidity": 3.64617969970703}, {"date": "2016-07-10T05:29:53Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_052953", "humidity": 4.02400886230469}, {"date": "2016-07-10T05:52:28Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_055228", "humidity": 3.52992457275391}, {"date": "2016-07-10T06:16:17Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_061617", "humidity": 3.14240748291016}, {"date": "2016-07-10T06:38:54Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_063854", "humidity": 3.59774006347656}, {"date": "2016-07-10T07:02:43Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_070243", "humidity": 3.79149860839844}, {"date": "2016-07-10T07:25:19Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_072519", "humidity": 3.50086079101563}, {"date": "2016-07-10T07:48:29Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_074829", "humidity": 4.19839155273438}, {"date": "2016-07-10T08:11:42Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_081142", "humidity": 3.92712958984375}, {"date": "2016-07-10T08:34:55Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_083455", "humidity": 3.96588129882813}, {"date": "2016-07-10T08:58:06Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_085806", "humidity": 4.4793414428711}, {"date": "2016-07-10T09:21:19Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_092119", "humidity": 3.78181068115235}, {"date": "2016-07-10T09:45:08Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_094508", "humidity": 3.58805213623047}, {"date": "2016-07-10T10:07:44Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_100744", "humidity": 3.64617969970703}, {"date": "2016-07-10T10:31:32Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_103132", "humidity": 3.99494508056641}, {"date": "2016-07-10T10:54:08Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_105408", "humidity": 4.12088813476563}, {"date": "2016-07-10T11:17:56Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_111756", "humidity": 4.45027766113281}, {"date": "2016-07-10T11:40:32Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_114032", "humidity": 3.36522980957031}, {"date": "2016-07-10T12:03:44Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_120344", "humidity": 4.55684486083985}, {"date": "2016-07-10T12:27:31Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_122731", "humidity": 3.43304530029297}, {"date": "2016-07-10T12:50:10Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_125010", "humidity": 3.43304530029297}, {"date": "2016-07-10T13:13:21Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_131321", "humidity": 4.1693277709961}, {"date": "2016-07-10T13:36:34Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_133634", "humidity": 1.51483570556641}, {"date": "2016-07-10T14:00:19Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_140019", "humidity": 3.49117286376953}, {"date": "2016-07-10T14:22:58Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_142258", "humidity": 4.14995191650391}, {"date": "2016-07-10T14:46:09Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_144609", "humidity": 4.10151228027344}, {"date": "2016-07-10T15:09:22Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_150922", "humidity": 3.10365577392578}, {"date": "2016-07-10T15:32:35Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_153235", "humidity": 3.63649177246094}, {"date": "2016-07-10T15:55:46Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_155546", "humidity": 2.97771271972656}, {"date": "2016-07-10T16:19:00Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_161900", "humidity": 3.37491773681641}, {"date": "2016-07-10T16:42:11Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_164211", "humidity": 3.52992457275391}, {"date": "2016-07-10T17:05:23Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_170523", "humidity": 4.25651911621094}, {"date": "2016-07-10T17:28:36Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_172836", "humidity": 3.72368311767578}, {"date": "2016-07-10T17:51:48Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_175148", "humidity": 4.6343482788086}, {"date": "2016-07-10T18:15:00Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_181500", "humidity": 4.67309998779297}, {"date": "2016-07-10T18:38:51Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_183851", "humidity": 4.19839155273438}, {"date": "2016-07-10T19:01:24Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_190124", "humidity": 3.43304530029297}, {"date": "2016-07-10T19:24:37Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_192437", "humidity": 3.87868995361328}, {"date": "2016-07-10T19:48:29Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_194829", "humidity": 3.72368311767578}, {"date": "2016-07-10T20:40:16Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_204016", "humidity": 3.98525715332031}, {"date": "2016-07-10T21:03:29Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_210329", "humidity": 3.89806580810547}, {"date": "2016-07-10T21:27:15Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_212715", "humidity": 3.63649177246094}, {"date": "2016-07-10T21:49:53Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_214953", "humidity": 3.93681751708985}, {"date": "2016-07-10T22:13:06Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_221306", "humidity": 3.49117286376953}, {"date": "2016-07-10T22:32:57Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_223257", "humidity": 6.47505445556641}, {"date": "2016-07-10T22:36:18Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_223618", "humidity": 3.75274689941406}, {"date": "2016-07-10T22:55:48Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_225548", "humidity": 3.68493140869141}, {"date": "2016-07-10T22:59:30Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_225930", "humidity": 4.66341206054688}, {"date": "2016-07-10T23:18:49Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_231849", "humidity": 4.80873096923828}, {"date": "2016-07-10T23:22:42Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_232242", "humidity": 3.91744166259766}, {"date": "2016-07-10T23:41:21Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_234121", "humidity": 4.19839155273438}, {"date": "2016-07-10T23:45:54Z", "pid": "http://ifcb-data.whoi.edu/mvco/IFCB5_2016_192_234554", "humidity": 4.48902937011719}]

# %%
hd=pd.DataFrame(humid)

py=pd.to_datetime(hd.date)

hd=hd.set_index(py,drop=False)

hd = hd.drop('date', 1)
hd = hd.drop('pid', 1)

#convert into time series
hd.humidity.name="Humidity"
s=pd.Series(hd.humidity,hd.index)
#changes frequency to 20 minute intervals
S=s.resample('20T', how='sum')
S
ts = S.cumsum()
S
# Out:
# date
# 2016-07-10 00:00:00     3.675243
# 2016-07-10 00:20:00          NaN
# 2016-07-10 00:40:00     3.423357
# 2016-07-10 01:00:00     3.956193
# 2016-07-10 01:20:00     3.733371
# 2016-07-10 01:40:00          NaN
# 2016-07-10 02:00:00     3.258663
# 2016-07-10 02:20:00     3.743059
# 2016-07-10 02:40:00     4.179016
# 2016-07-10 03:00:00     3.123032
# 2016-07-10 03:20:00     3.898066
# 2016-07-10 03:40:00     4.411526
# 2016-07-10 04:00:00          NaN
# 2016-07-10 04:20:00     3.849626
# 2016-07-10 04:40:00     3.888378
# 2016-07-10 05:00:00     3.646180
# 2016-07-10 05:20:00     4.024009
# 2016-07-10 05:40:00     3.529925
# 2016-07-10 06:00:00     3.142407
# 2016-07-10 06:20:00     3.597740
# 2016-07-10 06:40:00          NaN
# 2016-07-10 07:00:00     3.791499
# 2016-07-10 07:20:00     3.500861
# 2016-07-10 07:40:00     4.198392
# 2016-07-10 08:00:00     3.927130
# 2016-07-10 08:20:00     3.965881
# 2016-07-10 08:40:00     4.479341
# 2016-07-10 09:00:00          NaN
# ...

# %%
S.describe()
# Out:
# count    61.000000
# mean      4.046258
# std       1.271549
# min       1.514836
# 25%       3.529925
# 50%       3.849626
# 75%       4.149952
# max      10.227801
# Name: humidity, dtype: float64

# %%
S2=S.take(np.random.permutation(len(S)))
S2.sort_index()
S.index[0]
# Out:
# Timestamp('2016-07-10 00:00:00', offset='20T')

# %%
#using dataframe to plot a time series
H_D=pd.DataFrame
Nhd=S.to_frame(H_D)
Nhd
Nhd.columns = ['Humidity']#rename column
Nhd
# Out:
#                       Humidity
# date
# 2016-07-10 00:00:00   3.675243
# 2016-07-10 00:20:00        NaN
# 2016-07-10 00:40:00   3.423357
# 2016-07-10 01:00:00   3.956193
# 2016-07-10 01:20:00   3.733371
# 2016-07-10 01:40:00        NaN
# 2016-07-10 02:00:00   3.258663
# 2016-07-10 02:20:00   3.743059
# 2016-07-10 02:40:00   4.179016
# 2016-07-10 03:00:00   3.123032
# 2016-07-10 03:20:00   3.898066
# 2016-07-10 03:40:00   4.411526
# 2016-07-10 04:00:00        NaN
# 2016-07-10 04:20:00   3.849626
# 2016-07-10 04:40:00   3.888378
# 2016-07-10 05:00:00   3.646180
# 2016-07-10 05:20:00   4.024009
# 2016-07-10 05:40:00   3.529925
# 2016-07-10 06:00:00   3.142407
# 2016-07-10 06:20:00   3.597740
# 2016-07-10 06:40:00        NaN
# 2016-07-10 07:00:00   3.791499
# 2016-07-10 07:20:00   3.500861
# 2016-07-10 07:40:00   4.198392
# 2016-07-10 08:00:00   3.927130
# 2016-07-10 08:20:00   3.965881
# 2016-07-10 08:40:00   4.479341
# 2016-07-10 09:00:00        NaN
# 2016-07-10 09:20:00   3.781811
# ...

# %%
close_px=Nhd['Humidity']
close_px.head()
# Out:
# date
# 2016-07-10 00:00:00    3.675243
# 2016-07-10 00:20:00         NaN
# 2016-07-10 00:40:00    3.423357
# 2016-07-10 01:00:00    3.956193
# 2016-07-10 01:20:00    3.733371
# Freq: 20T, Name: Humidity, dtype: float64

# %%
close_px.plot(label='Humidity')
plt.legend()
plt.show()

# %%
px=hd['humidity']
px.head()
px.plot(label='humidity')
plt.legend()
plt.show()

# %%
r=requests.get('http://ifcb-data.whoi.edu/mvco/api/feed//temperature/start/2016-06-01/end/2016-07-02')
feed=r.json()
feed
fd=pd.DataFrame(feed)
fd
Py=pd.to_datetime(fd.date)
fd=fd.set_index(Py,drop=False)
fd
fd = fd.drop('date', 1)
fd=fd.drop('temperature',1)
fd

fd['pid']=fd['pid']+'_class_scores.csv'

# %%
fd["Cerataulina Count"] = ""
# Out:
#                                                                    pid  \
# date
# 2016-06-10 18:50:37  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 19:10:30  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 19:33:43  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 19:56:55  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 20:20:07  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 20:43:20  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 21:06:31  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 21:29:45  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 21:52:56  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 22:16:09  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 22:39:51  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 23:02:33  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# ...

# %%
for url in fd['pid']:
    
    dataf=pd.read_csv(url,index_col='pid')
    dataf.columns
    DF=dataf.idxmax(axis='columns', skipna=True)
    DF.index
    DDF=pd.DataFrame(DF)
    DDF.columns = ['Classification']#rename column
    Count=(DDF=="Cerataulina").sum()
    COUNT=Count.Classification

# %%
fd
# Out:
#                                                                    pid  \
# date
# 2016-06-10 18:50:37  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 19:10:30  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 19:33:43  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 19:56:55  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 20:20:07  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 20:43:20  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 21:06:31  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 21:29:45  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 21:52:56  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 22:16:09  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 22:39:51  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# 2016-06-10 23:02:33  http://ifcb-data.whoi.edu/mvco/IFCB5_2016_162_...
# ...

# %%
# Out:
#                     date  humidity  \
# 0   2016-07-10T00:17:50Z  3.675243
# 1   2016-07-10T00:50:50Z  3.423357
# 2   2016-07-10T01:14:01Z  3.956193
# 3   2016-07-10T01:37:48Z  3.733371
# 4   2016-07-10T02:01:01Z  3.258663
# 5   2016-07-10T02:23:39Z  3.743059
# 6   2016-07-10T02:47:26Z  4.179016
# 7   2016-07-10T03:10:38Z  3.123032
# 8   2016-07-10T03:33:16Z  3.898066
# 9   2016-07-10T03:56:27Z  4.411526
# 10  2016-07-10T04:20:17Z  3.849626
# 11  2016-07-10T04:42:53Z  3.888378
# 12  2016-07-10T05:06:04Z  3.646180
# 13  2016-07-10T05:29:53Z  4.024009
# 14  2016-07-10T05:52:28Z  3.529925
# 15  2016-07-10T06:16:17Z  3.142407
# 16  2016-07-10T06:38:54Z  3.597740
# 17  2016-07-10T07:02:43Z  3.791499
# 18  2016-07-10T07:25:19Z  3.500861
# 19  2016-07-10T07:48:29Z  4.198392
# 20  2016-07-10T08:11:42Z  3.927130
# 21  2016-07-10T08:34:55Z  3.965881
# 22  2016-07-10T08:58:06Z  4.479341
# 23  2016-07-10T09:21:19Z  3.781811
# 24  2016-07-10T09:45:08Z  3.588052
# ...

# %%
import requests
r=requests.get('http://ifcb-data.whoi.edu/mvco/feed.json')
feed=r.json()
first=feed[0]['pid']
R=first+'.csv'

# %%
#http://ifcb-data.whoi.edu/mvco/IFCB5_2016_189_162753.csv
R
# Out:
# u'http://ifcb-data.whoi.edu/mvco/IFCB5_2016_190_143632.csv'

# %%
import pandas as pd
R='http://ifcb-data.whoi.edu/mvco/IFCB5_2016_189_162753.csv'

dataf=pd.read_csv(R)
dataf.head()
# Out:
#    trigger  processingEndTime  fluorescenceLow  fluoresenceHigh  \
# 0        1           21.50000         0.044250        -0.345764
# 1        4           23.33203         0.055847        -0.036926
# 2        6           23.80469         0.007324        -1.049194
# 3        8           24.12500         0.051575        -0.091248
# 4       10           24.46484         0.064392        -0.028076
#
#    scatteringLow  scatteringHigh  comparatorPulse  triggerOpenTime  \
# 0       0.029907       -1.103210        -0.333557          0.00000
# 1       0.070496        0.040588        -0.237122         23.23047
# 2      -0.177307       -2.790833        -0.397339         23.57422
# 3      -0.456848       -3.094788        -0.254211         24.02344
# 4       0.071716        0.081787        -0.244446         24.39453
#
#    frameGrabTime  bottom  left  height  width  byteOffset  valveStatus  \
# 0       21.44922      68   515     114     53           1    -0.334167
# ...

# %%
#get values from specific column
dataf['height']
# Out:
# 0       113
# 1       105
# 2       105
# 3       105
# 4        97
# 5       105
# 6       105
# 7        96
# 8       105
# 9       105
# 10      114
# 11      105
# 12      113
# 13      105
# 14      113
# 15       96
# 16      105
# 17      113
# 18      122
# 19      396
# 20       97
# 21       97
# 22      105
# 23      105
# 24      113
# 25      113
# 26      105
# 27      105
# 28      172
# 29      105
#        ...
# 7139    105
# 7140    130
# 7141    121
# 7142    105
# 7143    105
# 7144    105
# 7145    105
# 7146    113
# 7147    105
# 7148    105
# 7149    105
# 7150    114
# 7151     97
# 7152    105
# 7153    114
# 7154    105
# 7155     97
# 7156    122
# 7157     97
# 7158     96
# 7159    113
# 7160    105
# 7161     96
# 7162    113
# 7163    105
# 7164    105
# 7165    530
# 7166    405
# 7167    113
# 7168    113
# Name: height, dtype: int64

# %%
df=pd.read_csv('http://ifcb-data.whoi.edu/mvco/IFCB1_2009_267_045932_features.csv')
df.head()
# Out:
#    roi_number  Area     Biovolume  BoundingBox_xwidth  BoundingBox_ywidth  \
# 0           1  4388  46352.660156                 288                  61
# 1           4   335   3441.614752                  24                  21
# 2           5   571   7805.286948                  32                  24
# 3           7   303   1733.087158                  33                  20
# 4           8  2656  51221.312022                 100                  63
#
#    ConvexArea  ConvexPerimeter  Eccentricity  EquivDiameter   Extent  \
# 0       10702          605.750       0.97844         74.746  0.24977
# 1         369           73.248       0.68603         20.653  0.66468
# 2         609           92.568       0.72760         26.963  0.74349
# 3         460           82.874       0.86446         19.642  0.45909
# 4        2892          248.320       0.96235         58.153  0.42159
#
#                ...                 HOG79    HOG80     HOG81  \
# ...

# %%
list(df.columns.values)
# Out:
# ['roi_number',
#  'Area',
#  'Biovolume',
#  'BoundingBox_xwidth',
#  'BoundingBox_ywidth',
#  'ConvexArea',
#  'ConvexPerimeter',
#  'Eccentricity',
#  'EquivDiameter',
#  'Extent',
#  'FeretDiameter',
#  'H180',
#  'H90',
#  'Hflip',
#  'MajorAxisLength',
#  'MinorAxisLength',
#  'Orientation',
#  'Perimeter',
#  'RWcenter2total_powerratio',
#  'RWhalfpowerintegral',
#  'Solidity',
#  'moment_invariant1',
#  'moment_invariant2',
#  'moment_invariant3',
#  'moment_invariant4',
#  'moment_invariant5',
#  'moment_invariant6',
#  'moment_invariant7',
#  'numBlobs',
#  'shapehist_kurtosis_normEqD',
#  'shapehist_mean_normEqD',
#  'shapehist_median_normEqD',
#  'shapehist_mode_normEqD',
#  'shapehist_skewness_normEqD',
#  'summedArea',
#  'summedConvexArea',
#  'summedConvexPerimeter',
#  'summedFeretDiameter',
#  'summedMajorAxisLength',
#  'summedMinorAxisLength',
#  'summedPerimeter',
#  'texture_average_contrast',
#  'texture_average_gray_level',
#  'texture_entropy',
# ...

# %%
#get column names in data frame
list(dataf.columns.values)
# Out:
# ['trigger',
#  'processingEndTime',
#  'fluorescenceLow',
#  'fluoresenceHigh',
#  'scatteringLow',
#  'scatteringHigh',
#  'comparatorPulse',
#  'triggerOpenTime',
#  'frameGrabTime',
#  'bottom',
#  'left',
#  'height',
#  'width',
#  'byteOffset',
#  'valveStatus',
#  'binID',
#  'pid',
#  'stitched',
#  'targetNumber']

# %%
import pandas as pd
df=pd.read_csv('http://ifcb-data.whoi.edu/mvco/IFCB5_2013_268_191006_class_scores.csv')
df.head()
# Out:
#                            pid  Asterionellopsis  Cerataulina  Ceratium  \
# 0  IFCB5_2013_268_191006_00002            0.0000       0.0000         0
# 1  IFCB5_2013_268_191006_00004            0.0100       0.0000         0
# 2  IFCB5_2013_268_191006_00005            0.0033       0.0000         0
# 3  IFCB5_2013_268_191006_00007            0.0033       0.0000         0
# 4  IFCB5_2013_268_191006_00008            0.0000       0.0167         0
#
#    Chaetoceros  Corethron  Coscinodiscus  Cylindrotheca  DactFragCerataul  \
# 0       0.0133       0.00              0         0.0000                 0
# 1       0.0167       0.00              0         0.0000                 0
# 2       0.0333       0.00              0         0.0067                 0
# 3       0.2367       0.00              0         0.0000                 0
# 4       0.0300       0.01              0         0.0000                 0
#
#    Dactyliosolen      ...       ciliate_mix  clusterflagellate  detritus  \
# ...

# %%
pd.date_range("11:00","21:30", freq='20min')
# Out:
# DatetimeIndex(['2016-07-11 11:00:00', '2016-07-11 11:20:00',
#                '2016-07-11 11:40:00', '2016-07-11 12:00:00',
#                '2016-07-11 12:20:00', '2016-07-11 12:40:00',
#                '2016-07-11 13:00:00', '2016-07-11 13:20:00',
#                '2016-07-11 13:40:00', '2016-07-11 14:00:00',
#                '2016-07-11 14:20:00', '2016-07-11 14:40:00',
#                '2016-07-11 15:00:00', '2016-07-11 15:20:00',
#                '2016-07-11 15:40:00', '2016-07-11 16:00:00',
#                '2016-07-11 16:20:00', '2016-07-11 16:40:00',
#                '2016-07-11 17:00:00', '2016-07-11 17:20:00',
#                '2016-07-11 17:40:00', '2016-07-11 18:00:00',
#                '2016-07-11 18:20:00', '2016-07-11 18:40:00',
#                '2016-07-11 19:00:00', '2016-07-11 19:20:00',
#                '2016-07-11 19:40:00', '2016-07-11 20:00:00',
#                '2016-07-11 20:20:00', '2016-07-11 20:40:00',
# ...

# %%
from datetime import datetime
# %matplotlib inline
import matplotlib.pyplot as pyplot

# %%
data = {'date': ['2014-05-01 18:47:05.069722', '2014-05-01 18:47:05.119994', '2014-05-02 18:47:05.178768', '2014-05-02 18:47:05.230071', '2014-05-02 18:47:05.230071', '2014-05-02 18:47:05.280592', '2014-05-03 18:47:05.332662', '2014-05-03 18:47:05.385109', '2014-05-04 18:47:05.436523', '2014-05-04 18:47:05.486877'], 
        'battle_deaths': [34, 25, 26, 15, 15, 14, 26, 25, 62, 41]}
df = pd.DataFrame(data, columns = ['date', 'battle_deaths'])
df
# Out:
#                          date  battle_deaths
# 0  2014-05-01 18:47:05.069722             34
# 1  2014-05-01 18:47:05.119994             25
# 2  2014-05-02 18:47:05.178768             26
# 3  2014-05-02 18:47:05.230071             15
# 4  2014-05-02 18:47:05.230071             15
# 5  2014-05-02 18:47:05.280592             14
# 6  2014-05-03 18:47:05.332662             26
# 7  2014-05-03 18:47:05.385109             25
# 8  2014-05-04 18:47:05.436523             62
# 9  2014-05-04 18:47:05.486877             41

# %%
df['date']=pd.to_datetime(df['date'])

# %%
df.shift(3)
# Out:
#                             battle_deaths
# date
# 2014-05-01 18:47:05.069722            NaN
# 2014-05-01 18:47:05.119994            NaN
# 2014-05-02 18:47:05.178768            NaN
# 2014-05-02 18:47:05.230071             34
# 2014-05-02 18:47:05.230071             25
# 2014-05-02 18:47:05.280592             26
# 2014-05-03 18:47:05.332662             15
# 2014-05-03 18:47:05.385109             15
# 2014-05-04 18:47:05.436523             14
# 2014-05-04 18:47:05.486877             26

# %%
df['2014-05']
# Out:
#                             battle_deaths
# date
# 2014-05-01 18:47:05.069722             34
# 2014-05-01 18:47:05.119994             25
# 2014-05-02 18:47:05.178768             26
# 2014-05-02 18:47:05.230071             15
# 2014-05-02 18:47:05.230071             15
# 2014-05-02 18:47:05.280592             14
# 2014-05-03 18:47:05.332662             26
# 2014-05-03 18:47:05.385109             25
# 2014-05-04 18:47:05.436523             62
# 2014-05-04 18:47:05.486877             41

# %%
df.truncate(after='5/3/2014')
# Out:
#                             battle_deaths
# date
# 2014-05-01 18:47:05.069722             34
# 2014-05-01 18:47:05.119994             25
# 2014-05-02 18:47:05.178768             26
# 2014-05-02 18:47:05.230071             15
# 2014-05-02 18:47:05.230071             15
# 2014-05-02 18:47:05.280592             14

# %%
df.groupby(level=0).count()
# Out:
#                             battle_deaths
# date
# 2014-05-01 18:47:05.069722              1
# 2014-05-01 18:47:05.119994              1
# 2014-05-02 18:47:05.178768              1
# 2014-05-02 18:47:05.230071              2
# 2014-05-02 18:47:05.280592              1
# 2014-05-03 18:47:05.332662              1
# 2014-05-03 18:47:05.385109              1
# 2014-05-04 18:47:05.436523              1
# 2014-05-04 18:47:05.486877              1

# %%
df.resample('D',how='sum').plot()

# %%
now=datetime.now()
now
# Out:
# datetime.datetime(2016, 7, 11, 13, 28, 42, 271192)

# %%
from dateutil.parser import parse

# %%
parse('Sep 26, 1995 10:44 PM')
# Out:
# datetime.datetime(1995, 9, 26, 22, 44)

# %%
from pandas.tseries.offsets import MonthEnd
now+MonthEnd()#output end of the month date
# Out:
# datetime.datetime(2016, 7, 11, 13, 28, 42, 271192)

# %%
offset=MonthEnd()
offset.rollback(now)
# Out:
# Timestamp('2016-06-30 13:28:42.271192')

# %%
import pytz

# %%
pytz.common_timezones[-24:]
#list timezones
# Out:
# ['Pacific/Nauru',
#  'Pacific/Niue',
#  'Pacific/Norfolk',
#  'Pacific/Noumea',
#  'Pacific/Pago_Pago',
#  'Pacific/Palau',
#  'Pacific/Pitcairn',
#  'Pacific/Pohnpei',
#  'Pacific/Port_Moresby',
#  'Pacific/Rarotonga',
#  'Pacific/Saipan',
#  'Pacific/Tahiti',
#  'Pacific/Tarawa',
#  'Pacific/Tongatapu',
#  'Pacific/Wake',
#  'Pacific/Wallis',
#  'US/Alaska',
#  'US/Arizona',
#  'US/Central',
#  'US/Eastern',
#  'US/Hawaii',
#  'US/Mountain',
#  'US/Pacific',
#  'UTC']

# %%
close_px_all=pd.read_csv('http://ifcb-data.whoi.edu/mvco/IFCB5_2013_268_191006.csv',parse_dates=True,index_col=0)
close_px=close_px_all[['fluorescenceLow','fluoresenceHigh','scatteringLow','scatteringHigh','comparatorPulse','triggerOpenTime','frameGrabTime','bottom','left','height','width','byteOffset','valveStatus','binID','pid','stitched','processingEndTime','targetNumber'
]]
close_px['frameGrabTime'].plot()

# %%
df = pd.read_csv('http://ifcb-data.whoi.edu/mvco/IFCB5_2013_268_191006.csv', sep=',', parse_dates=[0], header=None)
df
# Out:
#            0                  1                2                3   \
# 0     trigger  processingEndTime  fluorescenceLow  fluoresenceHigh
# 1           2          0.4453125   0.071716308594  -0.506896972656
# 2           4               0.75   0.075988769531  -0.266418457031
# 3           5          0.8203125   0.065002441406  -0.542602539062
# 4           7           1.632813   0.013122558594  -1.780090332031
# 5           8           1.929688   0.071411132812  -0.460205078125
# 6          11           3.914063   0.020141601562  -1.649169921875
# 7          12             4.1875   0.056457519531  -1.056213378906
# 8          14           4.578125   0.066223144531  -0.719299316406
# 9          15           4.710938   0.077819824219  -0.125732421875
# 10         16           5.007813    0.07568359375  -0.212707519531
# 11         17           5.195313   0.060424804688  -0.824584960938
# 12         18            5.53125   0.076904296875  -0.084533691406
# ...
